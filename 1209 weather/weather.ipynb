# %%
key = 'urz15HMZIl7GH7VC1sxsnGwRWNAHv%2Bfo9bhWTmlP3P9i3tELJ2oomcBTQtNZBIsxXi5PmFAcw1Yajfb3xvGPsA%3D%3D'

# %%
from datetime import datetime as dt
today = dt.today()
date = "%04d%02d%02d"%(today.year, today.month, today.day)

# %%
time = '0200'

# %%
url_api = 'http://apis.data.go.kr/1360000/VilageFcstInfoService/getVilageFcst?serviceKey={}&numOfRows=100&pageNo=1&base_date={}&base_time={}&nx=55&ny=127&dataType=JSON'.format(key,date,time)

# %%
print(url_api)
# Out:
# http://apis.data.go.kr/1360000/VilageFcstInfoService/getVilageFcst?serviceKey=urz15HMZIl7GH7VC1sxsnGwRWNAHv%2Bfo9bhWTmlP3P9i3tELJ2oomcBTQtNZBIsxXi5PmFAcw1Yajfb3xvGPsA%3D%3D&numOfRows=100&pageNo=1&base_date=20201209&base_time=0200&nx=55&ny=127&dataType=JSON

# %%
import requests
resp = requests.get(url_api)

# %%
data = resp.json()['response']['body']['items']['item']

# %%
for i in data:
    print(i['category'])
# Out:
# POP
# PTY
# R06
# REH
# S06
# SKY
# T3H
# TMN
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# REH
# SKY
# T3H
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# R06
# REH
# S06
# SKY
# T3H
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# REH
# SKY
# T3H
# TMX
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# R06
# REH
# S06
# SKY
# T3H
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# REH
# SKY
# T3H
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# R06
# REH
# S06
# SKY
# T3H
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# REH
# SKY
# T3H
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# R06
# REH
# S06
# SKY
# T3H
# TMN
# UUU
# VEC
# VVV
# WSD
# POP
# PTY
# REH
# SKY
# T3H
# UUU

# %%
import pandas as pd

# %%
data_df = pd.DataFrame(data)

# %%
data_df
# Out:
#     baseDate baseTime category  fcstDate fcstTime fcstValue  nx   ny
# 0   20201209     0200      POP  20201209     0600         0  55  127
# 1   20201209     0200      PTY  20201209     0600         0  55  127
# 2   20201209     0200      R06  20201209     0600         0  55  127
# 3   20201209     0200      REH  20201209     0600        70  55  127
# 4   20201209     0200      S06  20201209     0600         0  55  127
# ..       ...      ...      ...       ...      ...       ...  ..  ...
# 95  20201209     0200      PTY  20201210     0900         2  55  127
# 96  20201209     0200      REH  20201210     0900        95  55  127
# 97  20201209     0200      SKY  20201210     0900         4  55  127
# 98  20201209     0200      T3H  20201210     0900         3  55  127
# 99  20201209     0200      UUU  20201210     0900      -1.4  55  127
#
# [100 rows x 8 columns]

# %%
data_df.loc[:,['category','fcstValue']]
# Out:
#    category fcstValue
# 0       POP         0
# 1       PTY         0
# 2       R06         0
# 3       REH        70
# 4       S06         0
# ..      ...       ...
# 95      PTY         2
# 96      REH        95
# 97      SKY         4
# 98      T3H         3
# 99      UUU      -1.4
#
# [100 rows x 2 columns]

# %%
li = ["POP",'REH','SKY','TMN','TMX','T3H']
for i in li:
    display(data_df[data_df['category'] == i])
# Out:
#     baseDate baseTime category  fcstDate fcstTime fcstValue  nx   ny
# 0   20201209     0200      POP  20201209     0600         0  55  127
# 12  20201209     0200      POP  20201209     0900         7  55  127
# 21  20201209     0200      POP  20201209     1200        23  55  127
# 32  20201209     0200      POP  20201209     1500        30  55  127
# 42  20201209     0200      POP  20201209     1800        30  55  127
# 53  20201209     0200      POP  20201209     2100        30  55  127
# 62  20201209     0200      POP  20201210     0000        30  55  127
# 73  20201209     0200      POP  20201210     0300        60  55  127
# 82  20201209     0200      POP  20201210     0600        60  55  127
# 94  20201209     0200      POP  20201210     0900        60  55  127
#     baseDate baseTime category  fcstDate fcstTime fcstValue  nx   ny
#
# 68  20201210     0000      T3H         2
# 73  20201210     0300      POP        60
# 75  20201210     0300      REH        95
# 76  20201210     0300      SKY         4
# 77  20201210     0300      T3H         3
# 82  20201210     0600      POP        60
# 85  20201210     0600      REH       100
# 87  20201210     0600      SKY         4
# 88  20201210     0600      T3H         2
# 89  20201210     0600      TMN       2.0
# 94  20201210     0900      POP        60
# 96  20201210     0900      REH        95
# 97  20201210     0900      SKY         4
# 98  20201210     0900      T3H         3

# %%
data1.columns = ["일자","시간","정보","측정값"]

# %%
data1.loc[data1['정보']== 'POP', '정보'] = '강수확률'
data1.loc[data1['정보']== 'SKY', '정보'] = '하늘상태'
data1.loc[data1['정보']== 'TMN', '정보'] = '아침 최저기온'
data1.loc[data1['정보']== 'TMX', '정보'] = '낮 최고기온'

# %%
data2 = data1[data1['일자']==date]

# %%
data3 = data2[(data2['정보']=='강수확률') | (data2['정보']=='하늘상태') |(data2['정보']=='아침 최저기온')|(data2['정보']=='낮 최고기온')]

# %%
data3
# Out:
#           일자    시간       정보   측정값
# 0   20201209  0600     강수확률     0
# 5   20201209  0600     하늘상태     1
# 7   20201209  0600  아침 최저기온  -5.0
# 12  20201209  0900     강수확률     7
# 15  20201209  0900     하늘상태     1
# 21  20201209  1200     강수확률    23
# 26  20201209  1200     하늘상태     3
# 32  20201209  1500     강수확률    30
# 35  20201209  1500     하늘상태     4
# 37  20201209  1500   낮 최고기온   6.0
# 42  20201209  1800     강수확률    30
# 47  20201209  1800     하늘상태     4
# 53  20201209  2100     강수확률    30
# 56  20201209  2100     하늘상태     4

# %%
# 서비스 요청 시간을 02:10 이후로 설정하고 할것!

# %%
# sky = {'1':'맑음','3':'구름 맑음','4':'흐림'}

# %%
df = data2[data2['정보'] == '하늘상태']

# %%
def weather(n):
    if n == '1':
        return "맑음"
    if n == '3':
        return "구름 맑음"
    if n == '4':
        return "흐림"

# %%
weather_value = df['측정값']

# %%
sky = weather_value.apply(weather)

# %%
sky
# Out:
# 5        맑음
# 15       맑음
# 26    구름 맑음
# 35       흐림
# 47       흐림
# 56       흐림
# Name: 측정값, dtype: object

# %%
df['측정값'] = weather_value.apply(weather)
# Out:
# <ipython-input-526-17b8cf8d8782>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['측정값'] = weather_value.apply(weather)

# %%
data3[data3['정보'] == '하늘상태'] = df
# Out:
# <ipython-input-529-3dc4a89272a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3[data3['정보'] == '하늘상태'] = df
# C:\Users\SM809\anaconda3\lib\site-packages\pandas\core\frame.py:2957: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.loc._setitem_with_indexer(indexer, value)
# C:\Users\SM809\anaconda3\lib\site-packages\pandas\core\frame.py:2935: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_array(key, value)

# %%
data3
# Out:
#           일자    시간       정보    측정값
# 0   20201209  0600     강수확률      0
# 5   20201209  0600     하늘상태     맑음
# 7   20201209  0600  아침 최저기온   -5.0
# 12  20201209  0900     강수확률      7
# 15  20201209  0900     하늘상태     맑음
# 21  20201209  1200     강수확률     23
# 26  20201209  1200     하늘상태  구름 맑음
# 32  20201209  1500     강수확률     30
# 35  20201209  1500     하늘상태     흐림
# 37  20201209  1500   낮 최고기온    6.0
# 42  20201209  1800     강수확률     30
# 47  20201209  1800     하늘상태     흐림
# 53  20201209  2100     강수확률     30
# 56  20201209  2100     하늘상태     흐림
